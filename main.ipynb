# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
a=pd.read_csv('laptop_data.csv')

# %%
a.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %%
a.drop('Unnamed: 0',axis='columns')
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight        Price
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg   71378.6832
# 1           Intel HD Graphics 6000       macOS  1.34kg   47895.5232
# 2            Intel HD Graphics 620       No OS  1.86kg   30636.0000
# 3               AMD Radeon Pro 455       macOS  1.83kg  135195.3360
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg   96095.8080
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg   33992.6400
# 1299         Intel HD Graphics 520  Windows 10   1.3kg   79866.7200
# 1300             Intel HD Graphics  Windows 10   1.5kg   12201.1200
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg   40705.9200
# 1302             Intel HD Graphics  Windows 10   2.2kg   19660.3200
#
# [1303 rows x 11 columns]

# %%
a.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
a['Weight']=a['Weight'].str.replace('kg',' ')

# %%
a.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37    71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34    47895.5232
# 2         Intel HD Graphics 620  No OS  1.86    30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83   135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37    96095.8080

# %%
a['Ram']=a['Ram'].str.replace('GB',' ')

# %%
a.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8             128GB SSD
# 1        Intel Core i5 1.8GHz   8   128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8             256GB SSD
# 3        Intel Core i7 2.7GHz  16             512GB SSD
# 4        Intel Core i5 3.1GHz   8             256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37    71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34    47895.5232
# 2         Intel HD Graphics 620  No OS  1.86    30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83   135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37    96095.8080

# %%
a=a.astype({'Price':'int'})

# %%
a.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8             128GB SSD
# 1        Intel Core i5 1.8GHz   8   128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8             256GB SSD
# 3        Intel Core i7 2.7GHz  16             512GB SSD
# 4        Intel Core i5 3.1GHz   8             256GB SSD
#
#                             Gpu  OpSys Weight   Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37    71378
# 1        Intel HD Graphics 6000  macOS  1.34    47895
# 2         Intel HD Graphics 620  No OS  1.86    30636
# 3            AMD Radeon Pro 455  macOS  1.83   135195
# 4  Intel Iris Plus Graphics 650  macOS  1.37    96095

# %%
a['Ram'].astype('int')
# Out:
# 0        8
# 1        8
# 2        8
# 3       16
# 4        8
#         ..
# 1298     4
# 1299    16
# 1300     2
# 1301     6
# 1302     4
# Name: Ram, Length: 1303, dtype: int32

# %%
a['Weight'].astype('float32')
# Out:
# 0       1.37
# 1       1.34
# 2       1.86
# 3       1.83
# 4       1.37
#         ...
# 1298    1.80
# 1299    1.30
# 1300    1.50
# 1301    2.19
# 1302    2.20
# Name: Weight, Length: 1303, dtype: float32

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   int32
# dtypes: float64(1), int32(1), int64(1), object(9)
# memory usage: 117.2+ KB

# %%
import seaborn as sns

# %%
sns.distplot(a['Price'])
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_14408\1203898563.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a['Price'])
# <AxesSubplot: xlabel='Price', ylabel='Density'>

# %%
a['Company'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
sns.barplot(x=a['Company'],y=a['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
a['Price'].mean()
# Out:
# 59869.53952417498

# %%
a['TypeName'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
sns.barplot(x=a['TypeName'],y=a['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.displot(a['Inches'],kde=True)

# %%
sns.scatterplot(x=a['Inches'],y=a['Price'])
# Out:
# <AxesSubplot: xlabel='Inches', ylabel='Price'>

# %%
a['ScreenResolution'].value_counts()
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# IPS Panel Touchscreen 2560x1440                    5
# IPS Panel Retina Display 2880x1800                 4
# IPS Panel Touchscreen 1920x1200                    4
# 1440x900                                           4
# IPS Panel 2560x1440                                4
# IPS Panel Quad HD+ 2560x1440                       3
# Quad HD+ 3200x1800                                 3
# 1920x1080                                          3
# Touchscreen 2400x1600                              3
# 2560x1440                                          3
# IPS Panel Touchscreen 1366x768                     3
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# IPS Panel Full HD 2160x1440                        2
# IPS Panel Quad HD+ 3200x1800                       2
# IPS Panel Retina Display 2736x1824                 1
# IPS Panel Full HD 1920x1200                        1
# IPS Panel Full HD 2560x1440                        1
# IPS Panel Full HD 1366x768                         1
# Touchscreen / Full HD 1920x1080                    1
# Touchscreen / Quad HD+ 3200x1800                   1
# Touchscreen / 4K Ultra HD 3840x2160                1
# IPS Panel Touchscreen 2400x1600                    1
# Name: ScreenResolution, dtype: int64

# %%
a['Touchscreen']=a['ScreenResolution'].apply(lambda x:1 if 'Touchscreen ' in  x else 0)

# %%
a.sample(5)
# Out:
#       Unnamed: 0 Company  TypeName  Inches   ScreenResolution  \
# 637          637  Lenovo  Notebook    14.0           1366x768
# 1119        1119    Asus    Gaming    17.3  Full HD 1920x1080
# 134          134      HP  Notebook    15.6           1366x768
# 700          700    Dell    Gaming    15.6  Full HD 1920x1080
# 839          839    Asus  Notebook    15.6  Full HD 1920x1080
#
#                                        Cpu Ram                Memory  \
# 637   Intel Celeron Dual Core N3060 1.6GHz  2     32GB Flash Storage
# 1119           Intel Core i7 6700HQ 2.6GHz  8   128GB SSD +  1TB HDD
# 134             Intel Core i7 7500U 2.7GHz  8                1TB HDD
# 700            Intel Core i5 7300HQ 2.5GHz  8                1TB HDD
# 839             Intel Core i5 7200U 2.5GHz  8              128GB HDD
#
#                           Gpu       OpSys Weight  Price  Touchscreen
# 637     Intel HD Graphics 400  Windows 10  1.42   13266            0
# 1119  Nvidia GeForce GTX 960M  Windows 10  3.52   69929            0
# 134     Intel HD Graphics 620  Windows 10  2.05   31861            0
# 700   Nvidia GeForce GTX 1050  Windows 10  2.56   43636            0
# 839     Intel HD Graphics 620  Windows 10   2.3   31435            0

# %%
a['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
sns.barplot(x=a['Touchscreen'],y=a['Price'])
# Out:
# <AxesSubplot: xlabel='Touchscreen', ylabel='Price'>

# %%
a['Ips']=a['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
a.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8             128GB SSD
# 1        Intel Core i5 1.8GHz   8   128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8             256GB SSD
# 3        Intel Core i7 2.7GHz  16             512GB SSD
# 4        Intel Core i5 3.1GHz   8             256GB SSD
#
#                             Gpu  OpSys Weight   Price  Touchscreen  Ips
# 0  Intel Iris Plus Graphics 640  macOS  1.37    71378            0    1
# 1        Intel HD Graphics 6000  macOS  1.34    47895            0    0
# 2         Intel HD Graphics 620  No OS  1.86    30636            0    0
# 3            AMD Radeon Pro 455  macOS  1.83   135195            0    1
# 4  Intel Iris Plus Graphics 650  macOS  1.37    96095            0    1

# %%
a['Ips'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
new=a['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
a['X_res']=new[0]
a['Y_res']=new[1]

# %%
a.sample(15)
# Out:
#       Unnamed: 0 Company   TypeName  Inches  \
# 376          376  Lenovo    Netbook    11.6
# 925          925    Dell   Notebook    15.6
# 442          442  Lenovo  Ultrabook    12.5
# 337          337      HP   Notebook    15.6
# 61            61    Dell  Ultrabook    14.0
# 55            55    Dell   Notebook    15.6
# 1033        1033      HP   Notebook    14.0
# 1069        1069   Apple  Ultrabook    12.0
# 662          662  Lenovo   Notebook    15.6
# 605          605     MSI     Gaming    15.6
# 59            59    Asus   Notebook    15.6
# 72            72    Dell   Notebook    15.6
# 511          511    Acer   Notebook    15.6
# 484          484  Lenovo   Notebook    15.6
# 509          509  Lenovo     Gaming    15.6
#
#                         ScreenResolution  \
# 376                   IPS Panel 1366x768
# 925                             1366x768
# 442          IPS Panel Full HD 1920x1080
# 337                    Full HD 1920x1080
# 61                     Full HD 1920x1080
# 55                     Full HD 1920x1080
# 1033                   Full HD 1920x1080
# 1069  IPS Panel Retina Display 2304x1440
# 662                    Full HD 1920x1080
# 605                4K Ultra HD 3840x2160
# 59                     Full HD 1920x1080
# 72                     Full HD 1920x1080
# 511                    Full HD 1920x1080
# 484                             1366x768
# 509          IPS Panel Full HD 1920x1080
#
#                                        Cpu  Ram                Memory  \
# 376   Intel Celeron Quad Core N3450 1.1GHz   4              128GB SSD
# 925             Intel Core i5 6200U 2.3GHz   4              500GB HDD
# 442             Intel Core i5 7200U 2.5GHz   8              256GB SSD
# 337             Intel Core i5 7200U 2.5GHz   8              256GB SSD
# 61              Intel Core i5 8250U 1.6GHz   8              256GB SSD
# 55              Intel Core i7 8550U 1.8GHz   8              256GB SSD
# 1033            Intel Core i5 6200U 2.3GHz   8              256GB SSD
# 1069                   Intel Core M 1.1GHz   8    256GB Flash Storage
# 662             Intel Core i5 6200U 2.3GHz   4              500GB HDD
# 605            Intel Core i7 7700HQ 2.8GHz  16   256GB SSD +  2TB HDD
# 59                Intel Core i3 6006U 2GHz   4              256GB SSD
# 72              Intel Core i7 8550U 1.8GHz   8              256GB SSD
# 511             Intel Core i7 7500U 2.7GHz   4              500GB HDD
# 484             Intel Core i3 6006U 2.0GHz   4              128GB SSD
# 509            Intel Core i7 7700HQ 2.8GHz   8   256GB SSD +  1TB HDD
#
#                           Gpu       OpSys  Weight   Price  Touchscreen  Ips  \
# 376     Intel HD Graphics 500  Windows 10   1.59    29463            0    1
# 925     Intel HD Graphics 520  Windows 10   1.95    38889            0    0
# 442     Intel HD Graphics 620  Windows 10   1.36    76137            0    1
# 337     Intel HD Graphics 620  Windows 10   1.84    60952            0    0
# 61     Intel UHD Graphics 620  Windows 10    1.7    46833            0    0
# 55             AMD Radeon 520  Windows 10   2.13    40908            0    0
# 1033    Intel HD Graphics 520   Windows 7   1.95    63669            0    0
# 1069    Intel HD Graphics 515    Mac OS X  0.920    69264            0    1
# 662     Intel HD Graphics 520  Windows 10    2.2    28504            0    0
# 605   Nvidia GeForce GTX 1060  Windows 10    1.8   122490            0    0
# 59      Intel HD Graphics 520       Linux      2    22111            0    0
# 72             AMD Radeon 530  Windows 10    2.2    46353            0    0
# 511      Nvidia GeForce 940MX  Windows 10    2.2    34045            0    0
# 484     Intel HD Graphics 520  Windows 10    2.3    30103            0    0
# 509   Nvidia GeForce GTX 1060       No OS    2.4    61218            0    1
#
#                               X_res Y_res
# 376                  IPS Panel 1366   768
# 925                            1366   768
# 442          IPS Panel Full HD 1920  1080
# 337                    Full HD 1920  1080
# 61                     Full HD 1920  1080
# 55                     Full HD 1920  1080
# 1033                   Full HD 1920  1080
# 1069  IPS Panel Retina Display 2304  1440
# 662                    Full HD 1920  1080
# 605                4K Ultra HD 3840  2160
# 59                     Full HD 1920  1080
# 72                     Full HD 1920  1080
# 511                    Full HD 1920  1080
# 484                            1366   768
# 509          IPS Panel Full HD 1920  1080

# %%
a['X_res']=a['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
a.sample(15)
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 1146        1146      HP           Ultrabook    12.5
# 18            18  Lenovo            Notebook    15.6
# 26            26   Apple           Ultrabook    13.3
# 1165        1165    Dell              Gaming    15.6
# 903          903  Lenovo           Ultrabook    14.0
# 792          792  Lenovo  2 in 1 Convertible    13.3
# 1050        1050  Lenovo            Notebook    14.0
# 689          689  Lenovo            Notebook    15.6
# 35            35  Lenovo            Notebook    14.0
# 442          442  Lenovo           Ultrabook    12.5
# 374          374    Dell  2 in 1 Convertible    13.3
# 358          358    Dell            Notebook    15.6
# 305          305  Lenovo            Notebook    15.6
# 403          403    Acer            Notebook    15.6
# 774          774      HP           Ultrabook    12.5
#
#                                ScreenResolution  \
# 1146                          Full HD 1920x1080
# 18                            Full HD 1920x1080
# 26                                     1440x900
# 1165                      4K Ultra HD 3840x2160
# 903                 IPS Panel Full HD 1920x1080
# 792   IPS Panel Full HD / Touchscreen 1920x1080
# 1050                        IPS Panel 2560x1440
# 689                                    1366x768
# 35                                     1366x768
# 442                 IPS Panel Full HD 1920x1080
# 374             Full HD / Touchscreen 1920x1080
# 358                        Touchscreen 1366x768
# 305                                    1366x768
# 403                           Full HD 1920x1080
# 774                                    1366x768
#
#                                        Cpu  Ram                Memory  \
# 1146           Intel Core i7 6500U 2.50GHz   8              256GB SSD
# 18              Intel Core i3 7100U 2.4GHz   8                1TB HDD
# 26                    Intel Core i5 1.6GHz   8    128GB Flash Storage
# 1165           Intel Core i7 7700HQ 2.8GHz   8   128GB SSD +  1TB HDD
# 903             Intel Core i7 7500U 2.7GHz   8    256GB Flash Storage
# 792             Intel Core i7 7500U 2.7GHz   8              512GB SSD
# 1050            Intel Core i7 6600U 2.6GHz  16              256GB SSD
# 689   Intel Celeron Dual Core 3855U 1.6GHz   4              500GB HDD
# 35    Intel Celeron Dual Core N3350 1.1GHz   4     64GB Flash Storage
# 442             Intel Core i5 7200U 2.5GHz   8              256GB SSD
# 374             Intel Core i7 8550U 1.8GHz   8              256GB SSD
# 358             Intel Core i5 7200U 2.5GHz   8                2TB HDD
# 305   Intel Pentium Quad Core N4200 1.1GHz   4                1TB HDD
# 403            Intel Core i7 7700HQ 2.8GHz   8              256GB SSD
# 774             Intel Core i5 6200U 2.3GHz   4              256GB SSD
#
#                              Gpu       OpSys Weight   Price  Touchscreen  Ips  \
# 1146       Intel HD Graphics 520   Windows 7  1.26   122381            0    0
# 18          Nvidia GeForce 940MX       No OS   2.2    26586            0    0
# 26        Intel HD Graphics 6000    Mac OS X  1.35    58554            0    0
# 1165  Nvidia GeForce GTX 1050 Ti  Windows 10  2.62    79813            0    0
# 903        Intel HD Graphics 620  Windows 10  1.13   109170            0    1
# 792        Intel HD Graphics 620  Windows 10  1.37   104961            1    1
# 1050       Intel HD Graphics 520   Windows 7   1.1   139593            0    1
# 689        Intel HD Graphics 510  Windows 10   2.1    16943            0    0
# 35         Intel HD Graphics 500  Windows 10  1.44    13266            0    0
# 442        Intel HD Graphics 620  Windows 10  1.36    76137            0    1
# 374       Intel UHD Graphics 620  Windows 10  1.62    46300            1    0
# 358        Intel HD Graphics 620  Windows 10  2.36    29696            1    0
# 305        Intel HD Graphics 505       No OS   2.2    19180            0    0
# 403      Nvidia GeForce GTX 1050       Linux   2.5    46833            0    0
# 774        Intel HD Graphics 520  Windows 10  1.26    66280            0    0
#
#      X_res Y_res
# 1146  1920  1080
# 18    1920  1080
# 26    1440   900
# 1165  3840  2160
# 903   1920  1080
# 792   1920  1080
# 1050  2560  1440
# 689   1366   768
# 35    1366   768
# 442   1920  1080
# 374   1920  1080
# 358   1366   768
# 305   1366   768
# 403   1920  1080
# 774   1366   768

# %%
a['X_res']=a['X_res'].astype('int')
a['Y_res']=a['Y_res'].astype('int')

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   int32
#  12  Touchscreen       1303 non-null   int64
#  13  Ips               1303 non-null   int64
#  14  X_res             1303 non-null   int32
#  15  Y_res             1303 non-null   int32
# dtypes: float64(1), int32(3), int64(3), object(9)
# memory usage: 147.7+ KB

# %%
a.corr()['Price']
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_14408\3389678028.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   a.corr()['Price']
# Unnamed: 0     0.067985
# Inches         0.068196
# Price          1.000000
# Touchscreen    0.191226
# Ips            0.252207
# X_res          0.556529
# Y_res          0.552809
# Name: Price, dtype: float64

# %%
#ppi formula=sqrt(sqr(X_res)+sqr(Y_res))/inches

# %%
a['ppi']=((a['X_res']**2)+(a['Y_res']**2))**0.5/a['Inches'].astype('float')

# %%
a.corr()['Price']
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_14408\3389678028.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   a.corr()['Price']
# Unnamed: 0     0.067985
# Inches         0.068196
# Price          1.000000
# Touchscreen    0.191226
# Ips            0.252207
# X_res          0.556529
# Y_res          0.552809
# ppi            0.473487
# Name: Price, dtype: float64

# %%
a.drop(columns=['ScreenResolution'],inplace=True)

# %%
a.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                         Cpu  Ram  \
# 0           0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz   8
# 1           1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz   8
# 2           2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz   8
# 3           3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz  16
# 4           4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz   8
#
#                 Memory                           Gpu  OpSys Weight   Price  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37    71378
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34    47895
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86    30636
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83   135195
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37    96095
#
#    Touchscreen  Ips  X_res  Y_res         ppi
# 0            0    1   2560   1600  226.983005
# 1            0    0   1440    900  127.677940
# 2            0    0   1920   1080  141.211998
# 3            0    1   2880   1800  220.534624
# 4            0    1   2560   1600  226.983005

# %%
a.drop(columns=['Y_res'],inplace=True)

# %%
a.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                         Cpu  Ram  \
# 0           0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz   8
# 1           1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz   8
# 2           2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz   8
# 3           3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz  16
# 4           4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz   8
#
#                 Memory                           Gpu  OpSys Weight   Price  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37    71378
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34    47895
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86    30636
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83   135195
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37    96095
#
#    Touchscreen  Ips  X_res         ppi
# 0            0    1   2560  226.983005
# 1            0    0   1440  127.677940
# 2            0    0   1920  141.211998
# 3            0    1   2880  220.534624
# 4            0    1   2560  226.983005

# %%
a['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: Cpu, Length: 118, dtype: int64

# %%
a['Cpu Name']=a['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
a.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                         Cpu  Ram  \
# 0           0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz   8
# 1           1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz   8
# 2           2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz   8
# 3           3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz  16
# 4           4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz   8
#
#                 Memory                           Gpu  OpSys Weight   Price  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37    71378
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34    47895
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86    30636
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83   135195
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37    96095
#
#    Touchscreen  Ips  X_res         ppi       Cpu Name
# 0            0    1   2560  226.983005  Intel Core i5
# 1            0    0   1440  127.677940  Intel Core i5
# 2            0    0   1920  141.211998  Intel Core i5
# 3            0    1   2880  220.534624  Intel Core i7
# 4            0    1   2560  226.983005  Intel Core i5

# %%
def fetch_processor(text):
    if text=='Intel Core i7' or text=='Intel Core i5' or text=='Intel Core i3':
        return text
    else:
        if text.split()[0]=='Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
a['Cpu brand']=a['Cpu Name']=a['Cpu Name'].apply(fetch_processor)

# %%
a.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                         Cpu  Ram  \
# 0           0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz   8
# 1           1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz   8
# 2           2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz   8
# 3           3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz  16
# 4           4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz   8
#
#                 Memory                           Gpu  OpSys Weight   Price  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37    71378
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34    47895
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86    30636
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83   135195
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37    96095
#
#    Touchscreen  Ips  X_res         ppi       Cpu Name      Cpu brand
# 0            0    1   2560  226.983005  Intel Core i5  Intel Core i5
# 1            0    0   1440  127.677940  Intel Core i5  Intel Core i5
# 2            0    0   1920  141.211998  Intel Core i5  Intel Core i5
# 3            0    1   2880  220.534624  Intel Core i7  Intel Core i7
# 4            0    1   2560  226.983005  Intel Core i5  Intel Core i5

# %%
a['Cpu brand'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
sns.barplot(x=a['Cpu brand'],y=a['Price'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
a.drop(columns=['Cpu','Cpu Name'],inplace=True)

# %%
a.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches  Ram               Memory  \
# 0           0   Apple  Ultrabook    13.3   8             128GB SSD
# 1           1   Apple  Ultrabook    13.3   8   128GB Flash Storage
# 2           2      HP   Notebook    15.6   8             256GB SSD
# 3           3   Apple  Ultrabook    15.4  16             512GB SSD
# 4           4   Apple  Ultrabook    13.3   8             256GB SSD
#
#                             Gpu  OpSys Weight   Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS  1.37    71378            0    1
# 1        Intel HD Graphics 6000  macOS  1.34    47895            0    0
# 2         Intel HD Graphics 620  No OS  1.86    30636            0    0
# 3            AMD Radeon Pro 455  macOS  1.83   135195            0    1
# 4  Intel Iris Plus Graphics 650  macOS  1.37    96095            0    1
#
#    X_res         ppi      Cpu brand
# 0   2560  226.983005  Intel Core i5
# 1   1440  127.677940  Intel Core i5
# 2   1920  141.211998  Intel Core i5
# 3   2880  220.534624  Intel Core i7
# 4   2560  226.983005  Intel Core i5

# %%
a['Ram'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
sns.barplot(x=a['Ram'],y=a['Price'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
a['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 512GB SSD +  256GB SSD             1
# 512GB SSD +  512GB SSD             1
# 64GB Flash Storage +  1TB HDD      1
# 1TB HDD +  1TB HDD                 1
# 32GB HDD                           1
# 64GB SSD                           1
# 128GB HDD                          1
# 240GB SSD                          1
# 8GB SSD                            1
# 508GB Hybrid                       1
# 1.0TB HDD                          1
# 512GB SSD +  1.0TB Hybrid          1
# 256GB SSD +  1.0TB Hybrid          1
# Name: Memory, dtype: int64

# %%
a['Memory']=a['Memory'].astype(str).replace('\.0','',regex=True)
a["Memory"]=a["Memory"].str.replace('GB','')
a["Memory"]=a["Memory"].str.replace('TB','000')
new=a["Memory"].str.split("+",n=1,expand=True)

a["first"]=new[0]
a["first"]=a["first"].str.strip()

a["second"]=new[1]
a["Layer1HDD"]=a["first"].apply(lambda x:1 if "HDD" in x else 0)
a["Layer1SSD"]=a["first"].apply(lambda x:1 if "SSD" in x else 0)
a["Layer1Hybrid"]=a["first"].apply(lambda x:1 if "Hybrid" in x else 0)
a["Layer1Flash_Storage"]=a["first"].apply(lambda x:1 if "Flash_Storage" in x else 0)
a["first"]=a["first"].str.replace(r'\D','')
a["second"].fillna("0",inplace=True)

a["Layer2HDD"]=a["second"].apply(lambda x:1 if "HDD" in x else 0)
a["Layer2SSD"]=a["second"].apply(lambda x:1 if "SSD" in x else 0)
a["Layer2Hybrid"]=a["second"].apply(lambda x:1 if "Hybrid" in x else 0)
a["Layer2Flash_Storage"]=a["second"].apply(lambda x:1 if "Flash_Storage" in x else 0)

a["second"]=a["second"].str.replace(r'\D','')

a["first"]=a["first"].astype(int)
a["second"]=a["second"].astype(int)

a["HDD"]=(a["first"]*a["Layer1HDD"]+a["second"]*a["Layer2HDD"])
a["SSD"]=(a["first"]*a["Layer1SSD"]+a["second"]*a["Layer2SSD"])
a["Hybrid"]=(a["first"]*a["Layer1Hybrid"]+a["second"]*a["Layer2Hybrid"])
a["Flash_Storage"]=(a["first"]*a["Layer1Flash_Storage"]+a["second"]*a["Layer2Flash_Storage"])

a.drop(columns=['first','second','Layer1HDD','Layer1SSD','Layer1Hybrid','Layer1Flash_Storage','Layer2HDD','Layer2SSD','Layer2Hybrid','Layer2Flash_Storage'],inplace=True)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_14408\733695865.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   a["first"]=a["first"].str.replace(r'\D','')
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_14408\733695865.py:22: FutureWarning: The default value of regex will change from True to False in a future version.
#   a["second"]=a["second"].str.replace(r'\D','')

# %%
a.sample(5)
# Out:
#       Unnamed: 0 Company   TypeName  Inches  Ram               Memory  \
# 784          784  Lenovo  Ultrabook    14.0  16               512 SSD
# 993          993  Lenovo   Notebook    15.6   8               256 SSD
# 153          153     MSI     Gaming    17.3  16   256 SSD +  1000 HDD
# 1254        1254    Dell   Notebook    15.6   4               500 HDD
# 903          903  Lenovo  Ultrabook    14.0   8     256 Flash Storage
#
#                           Gpu       OpSys Weight   Price  Touchscreen  Ips  \
# 784     Intel HD Graphics 620  Windows 10   1.7   122490            0    0
# 993     Intel HD Graphics 520  Windows 10   2.3    71874            0    0
# 153   Nvidia GeForce GTX 1060  Windows 10   2.8   100699            0    0
# 1254        Intel HD Graphics  Windows 10   2.2    23655            0    0
# 903     Intel HD Graphics 620  Windows 10  1.13   109170            0    1
#
#       X_res         ppi              Cpu brand   HDD  SSD  Hybrid  \
# 784    1920  157.350512          Intel Core i7     0  512       0
# 993    1920  141.211998          Intel Core i5     0  256       0
# 153    1920  127.335675          Intel Core i7  1000  256       0
# 1254   1366  100.454670  Other Intel Processor   500    0       0
# 903    1920  157.350512          Intel Core i7     0    0       0
#
#       Flash_Storage
# 784               0
# 993               0
# 153               0
# 1254              0
# 903               0

# %%
a.drop(columns=['Memory'],inplace=True)

# %%
a.corr()['Price']
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_14408\3389678028.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   a.corr()['Price']
# Unnamed: 0       0.067985
# Inches           0.068196
# Price            1.000000
# Touchscreen      0.191226
# Ips              0.252207
# X_res            0.556529
# ppi              0.473487
# HDD             -0.096442
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage         NaN
# Name: Price, dtype: float64

# %%
a.drop(columns=['Hybrid'],inplace=True)

# %%
a.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches  Ram                           Gpu  \
# 0           0   Apple  Ultrabook    13.3   8   Intel Iris Plus Graphics 640
# 1           1   Apple  Ultrabook    13.3   8         Intel HD Graphics 6000
# 2           2      HP   Notebook    15.6   8          Intel HD Graphics 620
# 3           3   Apple  Ultrabook    15.4  16             AMD Radeon Pro 455
# 4           4   Apple  Ultrabook    13.3   8   Intel Iris Plus Graphics 650
#
#    OpSys Weight   Price  Touchscreen  Ips  X_res         ppi      Cpu brand  \
# 0  macOS  1.37    71378            0    1   2560  226.983005  Intel Core i5
# 1  macOS  1.34    47895            0    0   1440  127.677940  Intel Core i5
# 2  No OS  1.86    30636            0    0   1920  141.211998  Intel Core i5
# 3  macOS  1.83   135195            0    1   2880  220.534624  Intel Core i7
# 4  macOS  1.37    96095            0    1   2560  226.983005  Intel Core i5
#
#    HDD  SSD  Flash_Storage
# 0    0  128              0
# 1    0    0              0
# 2    0  256              0
# 3    0  512              0
# 4    0  256              0

# %%
a.drop(columns=['Flash_Storage'],inplace=True)

# %%
a.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches  Ram                           Gpu  \
# 0           0   Apple  Ultrabook    13.3   8   Intel Iris Plus Graphics 640
# 1           1   Apple  Ultrabook    13.3   8         Intel HD Graphics 6000
# 2           2      HP   Notebook    15.6   8          Intel HD Graphics 620
# 3           3   Apple  Ultrabook    15.4  16             AMD Radeon Pro 455
# 4           4   Apple  Ultrabook    13.3   8   Intel Iris Plus Graphics 650
#
#    OpSys Weight   Price  Touchscreen  Ips  X_res         ppi      Cpu brand  \
# 0  macOS  1.37    71378            0    1   2560  226.983005  Intel Core i5
# 1  macOS  1.34    47895            0    0   1440  127.677940  Intel Core i5
# 2  No OS  1.86    30636            0    0   1920  141.211998  Intel Core i5
# 3  macOS  1.83   135195            0    1   2880  220.534624  Intel Core i7
# 4  macOS  1.37    96095            0    1   2560  226.983005  Intel Core i5
#
#    HDD  SSD
# 0    0  128
# 1    0    0
# 2    0  256
# 3    0  512
# 4    0  256

# %%
a['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: Gpu, Length: 110, dtype: int64

# %%
a['Gpu_brand']=a['Gpu'].apply(lambda x:x.split()[0])

# %%
a.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches  Ram                           Gpu  \
# 0           0   Apple  Ultrabook    13.3   8   Intel Iris Plus Graphics 640
# 1           1   Apple  Ultrabook    13.3   8         Intel HD Graphics 6000
# 2           2      HP   Notebook    15.6   8          Intel HD Graphics 620
# 3           3   Apple  Ultrabook    15.4  16             AMD Radeon Pro 455
# 4           4   Apple  Ultrabook    13.3   8   Intel Iris Plus Graphics 650
#
#    OpSys Weight   Price  Touchscreen  Ips  X_res         ppi      Cpu brand  \
# 0  macOS  1.37    71378            0    1   2560  226.983005  Intel Core i5
# 1  macOS  1.34    47895            0    0   1440  127.677940  Intel Core i5
# 2  No OS  1.86    30636            0    0   1920  141.211998  Intel Core i5
# 3  macOS  1.83   135195            0    1   2880  220.534624  Intel Core i7
# 4  macOS  1.37    96095            0    1   2560  226.983005  Intel Core i5
#
#    HDD  SSD Gpu_brand
# 0    0  128     Intel
# 1    0    0     Intel
# 2    0  256     Intel
# 3    0  512       AMD
# 4    0  256     Intel

# %%
a['Gpu_brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: Gpu_brand, dtype: int64

# %%
a=a[a['Gpu_brand']!='ARM']

# %%
a.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches  Ram                           Gpu  \
# 0           0   Apple  Ultrabook    13.3   8   Intel Iris Plus Graphics 640
# 1           1   Apple  Ultrabook    13.3   8         Intel HD Graphics 6000
# 2           2      HP   Notebook    15.6   8          Intel HD Graphics 620
# 3           3   Apple  Ultrabook    15.4  16             AMD Radeon Pro 455
# 4           4   Apple  Ultrabook    13.3   8   Intel Iris Plus Graphics 650
#
#    OpSys Weight   Price  Touchscreen  Ips  X_res         ppi      Cpu brand  \
# 0  macOS  1.37    71378            0    1   2560  226.983005  Intel Core i5
# 1  macOS  1.34    47895            0    0   1440  127.677940  Intel Core i5
# 2  No OS  1.86    30636            0    0   1920  141.211998  Intel Core i5
# 3  macOS  1.83   135195            0    1   2880  220.534624  Intel Core i7
# 4  macOS  1.37    96095            0    1   2560  226.983005  Intel Core i5
#
#    HDD  SSD Gpu_brand
# 0    0  128     Intel
# 1    0    0     Intel
# 2    0  256     Intel
# 3    0  512       AMD
# 4    0  256     Intel

# %%
sns.barplot(x=a['Gpu_brand'],y=a['Price'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
a.drop(columns=['Gpu'],inplace=True)

# %%
a.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches  Ram  OpSys Weight   Price  \
# 0           0   Apple  Ultrabook    13.3   8   macOS  1.37    71378
# 1           1   Apple  Ultrabook    13.3   8   macOS  1.34    47895
# 2           2      HP   Notebook    15.6   8   No OS  1.86    30636
# 3           3   Apple  Ultrabook    15.4  16   macOS  1.83   135195
# 4           4   Apple  Ultrabook    13.3   8   macOS  1.37    96095
#
#    Touchscreen  Ips  X_res         ppi      Cpu brand  HDD  SSD Gpu_brand
# 0            0    1   2560  226.983005  Intel Core i5    0  128     Intel
# 1            0    0   1440  127.677940  Intel Core i5    0    0     Intel
# 2            0    0   1920  141.211998  Intel Core i5    0  256     Intel
# 3            0    1   2880  220.534624  Intel Core i7    0  512       AMD
# 4            0    1   2560  226.983005  Intel Core i5    0  256     Intel

# %%
a['OpSys'].value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
sns.barplot(x=a['OpSys'],y=a['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
def cat_os(inp):
    if inp=='Windows 10' or inp=='Windows 7' or inp=='Windows 10 S':
        return 'Windows'
    elif inp=='macOS' or inp=='Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

# %%
a['os']=a['OpSys'].apply(cat_os)

# %%
a.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches  Ram  OpSys Weight   Price  \
# 0           0   Apple  Ultrabook    13.3   8   macOS  1.37    71378
# 1           1   Apple  Ultrabook    13.3   8   macOS  1.34    47895
# 2           2      HP   Notebook    15.6   8   No OS  1.86    30636
# 3           3   Apple  Ultrabook    15.4  16   macOS  1.83   135195
# 4           4   Apple  Ultrabook    13.3   8   macOS  1.37    96095
#
#    Touchscreen  Ips  X_res         ppi      Cpu brand  HDD  SSD Gpu_brand  \
# 0            0    1   2560  226.983005  Intel Core i5    0  128     Intel
# 1            0    0   1440  127.677940  Intel Core i5    0    0     Intel
# 2            0    0   1920  141.211998  Intel Core i5    0  256     Intel
# 3            0    1   2880  220.534624  Intel Core i7    0  512       AMD
# 4            0    1   2560  226.983005  Intel Core i5    0  256     Intel
#
#                    os
# 0                 Mac
# 1                 Mac
# 2  Others/No OS/Linux
# 3                 Mac
# 4                 Mac

# %%
a.drop(columns=['OpSys'],inplace=True)

# %%
a.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches  Ram Weight   Price  Touchscreen  \
# 0           0   Apple  Ultrabook    13.3   8   1.37    71378            0
# 1           1   Apple  Ultrabook    13.3   8   1.34    47895            0
# 2           2      HP   Notebook    15.6   8   1.86    30636            0
# 3           3   Apple  Ultrabook    15.4  16   1.83   135195            0
# 4           4   Apple  Ultrabook    13.3   8   1.37    96095            0
#
#    Ips  X_res         ppi      Cpu brand  HDD  SSD Gpu_brand  \
# 0    1   2560  226.983005  Intel Core i5    0  128     Intel
# 1    0   1440  127.677940  Intel Core i5    0    0     Intel
# 2    0   1920  141.211998  Intel Core i5    0  256     Intel
# 3    1   2880  220.534624  Intel Core i7    0  512       AMD
# 4    1   2560  226.983005  Intel Core i5    0  256     Intel
#
#                    os
# 0                 Mac
# 1                 Mac
# 2  Others/No OS/Linux
# 3                 Mac
# 4                 Mac

# %%
sns.barplot(x=a['os'],y=a['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(a['Weight'],kde=True)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_14408\3041162568.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a['Weight'],kde=True)
# <AxesSubplot: xlabel='Weight', ylabel='Density'>

# %%
sns.scatterplot(x=a['Weight'],y=a['Price'])
# Out:
# <AxesSubplot: xlabel='Weight', ylabel='Price'>

# %%
a.drop(columns=['X_res'],inplace=True)

# %%
a['Weight']
# Out:
# 0       1.37
# 1       1.34
# 2       1.86
# 3       1.83
# 4       1.37
#         ...
# 1298     1.8
# 1299     1.3
# 1300     1.5
# 1301    2.19
# 1302     2.2
# Name: Weight, Length: 1302, dtype: object

# %%
sns.heatmap(a.corr())
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_14408\875251883.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(a.corr())
# <AxesSubplot: >

# %%
sns.distplot(np.log(a['Price']))
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_14408\632839409.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(a['Price']))
# <AxesSubplot: xlabel='Price', ylabel='Density'>

# %%
a.drop(columns=['Inches'],inplace=True)
a.drop(columns=['Unnamed: 0'],inplace=True)
X=a.drop(columns=['Price'])
y=np.log(a['Price'])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.15,random_state=2)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from xgboost import XGBRegressor
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error
from sklearn.svm import SVR

# %%
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
        ],remainder='passthrough')
step2=LinearRegression()
pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.807328559344045
# MAE 0.21018098624043777

# %%
a.shape
# Out:
# (1302, 13)

# %%
a.head()
# Out:
#   Company   TypeName  Ram Weight   Price  Touchscreen  Ips         ppi  \
# 0   Apple  Ultrabook   8   1.37    71378            0    1  226.983005
# 1   Apple  Ultrabook   8   1.34    47895            0    0  127.677940
# 2      HP   Notebook   8   1.86    30636            0    0  141.211998
# 3   Apple  Ultrabook  16   1.83   135195            0    1  220.534624
# 4   Apple  Ultrabook   8   1.37    96095            0    1  226.983005
#
#        Cpu brand  HDD  SSD Gpu_brand                  os
# 0  Intel Core i5    0  128     Intel                 Mac
# 1  Intel Core i5    0    0     Intel                 Mac
# 2  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3  Intel Core i7    0  512       AMD                 Mac
# 4  Intel Core i5    0  256     Intel                 Mac

# %%
X_train
# Out:
#       Company            TypeName  Ram  Weight  Touchscreen  Ips         ppi  \
# 183   Toshiba            Notebook   8     2.0             0    0  100.454670
# 1141      MSI              Gaming   8     2.4             0    0  141.211998
# 1049     Asus             Netbook   4     1.2             0    0  135.094211
# 1020     Dell  2 in 1 Convertible   4    2.08             1    1  141.211998
# 878      Dell            Notebook   4    2.18             0    0  141.211998
# ...       ...                 ...  ...     ...          ...  ...         ...
# 466      Acer            Notebook   4     2.2             0    0  100.454670
# 299      Asus           Ultrabook  16    1.63             0    0  141.211998
# 493      Acer            Notebook   8     2.2             0    0  100.454670
# 527    Lenovo            Notebook   8     2.2             0    0  100.454670
# 1193    Apple           Ultrabook   8   0.920             0    1  226.415547
#
#                   Cpu brand   HDD  SSD Gpu_brand                  os
# 183           Intel Core i5     0  128     Intel             Windows
# 1141          Intel Core i7  1000  128    Nvidia             Windows
# 1049  Other Intel Processor     0    0     Intel  Others/No OS/Linux
# 1020          Intel Core i3  1000    0     Intel             Windows
# 878           Intel Core i5  1000  128    Nvidia             Windows
# ...                     ...   ...  ...       ...                 ...
# 466           Intel Core i3   500    0    Nvidia             Windows
# 299           Intel Core i7     0  512    Nvidia             Windows
# 493           AMD Processor  1000    0       AMD             Windows
# 527           Intel Core i3  2000    0    Nvidia  Others/No OS/Linux
# 1193  Other Intel Processor     0    0     Intel                 Mac
#
# [1106 rows x 12 columns]

# %%
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
        ],remainder='passthrough')
step2=Ridge(alpha=10)
pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8127336192333607
# MAE 0.20927097416106621

# %%
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
        ],remainder='passthrough')
step2=Lasso(alpha=0.001)
pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8071862230993045
# MAE 0.21114642964758448

# %%
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
        ],remainder='passthrough')
step2=KNeighborsRegressor(n_neighbors=3)
pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8030028864909671
# MAE 0.1928220519192121

# %%
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
        ],remainder='passthrough')
step2=DecisionTreeRegressor(max_depth=8)
pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.838124688530559
# MAE 0.18281221449686566

# %%
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
        ],remainder='passthrough')
step2=SVR(kernel='rbf',C=10000,epsilon=0.1)
pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8083066394118655
# MAE 0.202413949574152

# %%
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
        ],remainder='passthrough')
step2=RandomForestRegressor(n_estimators=100,
                           random_state=3,
                           max_samples=0.5,
                           max_features=0.75,
                           max_depth=15)
pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8856428805715316
# MAE 0.1596519819734155

# %%
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
        ],remainder='passthrough')
step2=ExtraTreesRegressor(n_estimators=100,
                           random_state=3,
                           max_samples=None,
                           max_features=0.75,
                           max_depth=15)
pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8759728151226072
# MAE 0.1608022109570239

# %%
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
        ],remainder='passthrough')
step2=AdaBoostRegressor(n_estimators=15,
                           learning_rate=1.0)
pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7989799898019843
# MAE 0.22796498212252217

# %%
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
        ],remainder='passthrough')
step2=GradientBoostingRegressor(n_estimators=500)
pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8803033266271298
# MAE 0.15978060759387955

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')


estimators = [
    ('rf', RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15))
]

step2 = StackingRegressor(estimators=estimators, final_estimator=Ridge(alpha=100))

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# C:\Users\lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.848054124813794
# MAE 0.18600472206459764

# %%
import pickle

pickle.dump(a,open('a.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
a.head()

# %%
X_train
# Out:
#       Company            TypeName  Ram  Weight  Touchscreen  Ips         ppi  \
# 183   Toshiba            Notebook   8     2.0             0    0  100.454670
# 1141      MSI              Gaming   8     2.4             0    0  141.211998
# 1049     Asus             Netbook   4     1.2             0    0  135.094211
# 1020     Dell  2 in 1 Convertible   4    2.08             1    1  141.211998
# 878      Dell            Notebook   4    2.18             0    0  141.211998
# ...       ...                 ...  ...     ...          ...  ...         ...
# 466      Acer            Notebook   4     2.2             0    0  100.454670
# 299      Asus           Ultrabook  16    1.63             0    0  141.211998
# 493      Acer            Notebook   8     2.2             0    0  100.454670
# 527    Lenovo            Notebook   8     2.2             0    0  100.454670
# 1193    Apple           Ultrabook   8   0.920             0    1  226.415547
#
#                   Cpu brand   HDD  SSD Gpu_brand                  os
# 183           Intel Core i5     0  128     Intel             Windows
# 1141          Intel Core i7  1000  128    Nvidia             Windows
# 1049  Other Intel Processor     0    0     Intel  Others/No OS/Linux
# 1020          Intel Core i3  1000    0     Intel             Windows
# 878           Intel Core i5  1000  128    Nvidia             Windows
# ...                     ...   ...  ...       ...                 ...
# 466           Intel Core i3   500    0    Nvidia             Windows
# 299           Intel Core i7     0  512    Nvidia             Windows
# 493           AMD Processor  1000    0       AMD             Windows
# 527           Intel Core i3  2000    0    Nvidia  Others/No OS/Linux
# 1193  Other Intel Processor     0    0     Intel                 Mac
#
# [1106 rows x 12 columns]
